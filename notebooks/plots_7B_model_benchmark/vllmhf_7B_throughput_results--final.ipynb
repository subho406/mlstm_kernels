# %%
# %load_ext autoreload
# %autoreload 2
import sys

import pandas as pd

sys.path.append("../..")

from mlstm_kernels.utils.benchmark.plot_results import (
    plot_benchmark_result_table,
    create_runtime_bar_plot,
    rc_context_wrapper,
    select_columns,
    savefig,
)
from pathlib import Path
from plot_config import linestyle_mapping, style_dict
import pickle
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def load_throughput_results_for_ctxes(path_template: str, ctxes: list[int]):
    results = {}
    for ctx in ctxes:
        path = Path(path_template.format(ctx=ctx))
        df = pd.read_csv(path).filter(regex=".*(batch_size|prefill|R--).*")
        results[ctx] = df
    return results

# %%
# llama_results = load_throughput_results_for_ctxes(
#     path_template="/home/beck/wdir/dev_repos/mlstm_kernels/outputs_kernel_benchmarks_final/2024-12-06_19-44-48__throughput__forward_llama_v3/hf_7B_throughput__pfl{ctx}_gl0_tcTrue_weightdtypebfloat16/results.csv",
#     ctxes=[2048, 4096, 8192, 16384, 32768],
# )

# mamba_results = load_throughput_results_for_ctxes(
#     path_template="/home/beck/wdir/dev_repos/mlstm_kernels/outputs_kernel_benchmarks_final/2024-12-06_13-02-27__throughput__forward_mamba_v2/hf_7B_throughput__pfl{ctx}_gl0_tcTrue_weightdtypebfloat16/results.csv",
#     ctxes=[2048, 4096, 8192, 16384, 32768],
# )

# mxlstm_results = load_throughput_results_for_ctxes(
#     path_template="/home/beck/wdir/dev_repos/mlstm_kernels/outputs_kernel_benchmarks_final/2024-12-06_12-46-45__throughput__forward_xlstm_v0/hf_7B_throughput__pfl{ctx}_gl0_tcTrue_weightdtypebfloat16/results.csv",
#     ctxes=[2048, 4096, 8192, 16384, 32768],
# )

# %%
# # collect all results sorted by context
# result_dicts = [
#     llama_results,
#     mamba_results,
#     mxlstm_results,
# ]
# combined_raw_data = {}
# for ctx in [2048, 4096, 8192, 16384, 32768]:
#     ctx_df = pd.concat(
#         [rd[ctx].set_index("P--batch_size") for rd in result_dicts], axis=1
#     )
#     # select batch size only once
#     ctx_df = pd.concat(
#         [
#             ctx_df.filter(regex="prefill").take([0], axis=1),
#             ctx_df.filter(regex=".*R--.*"),
#         ],
#         axis=1,
#     )
#     combined_raw_data[ctx] = ctx_df

# %%
# with open("throughput_data.p", "wb") as f:
#     pickle.dump(combined_raw_data, f)

# for k, v in combined_raw_data.items():
#     v.to_csv(f"raw_data_throughput_{k}.csv")

# %%
with open("throughput_data.p", "rb") as f:
    combined_raw_data = pickle.load(f)

# %%
combined_raw_data[2048]
# Out:
#                P--prefill_length  \
# P--batch_size
# 1                         2048.0
# 2                         2048.0
# 4                         2048.0
# 8                         2048.0
# 16                        2048.0
# 32                        2048.0
# 64                        2048.0
# 128                          NaN
#
#                R--llama2__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1                                                      47.332440
# 2                                                      91.504448
# 4                                                     191.143909
# 8                                                     379.785248
# 16                                                    762.409790
# 32                                                   1538.071442
# 64                                                           NaN
# 128                                                          NaN
#
#                R--llama3__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1                                                      52.418256
# 2                                                     103.846966
# 4                                                     215.597393
# 8                                                     426.422531
# 16                                                    869.689636
# 32                                                   1736.462799
# 64                                                           NaN
# 128                                                          NaN
#
#                R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1                                                      72.727154
# 2                                                            NaN
# 4                                                     290.252129
# 8                                                     582.758759
# 16                                                   1184.665649
# 32                                                   2403.081787
# 64                                                           NaN
# 128                                                          NaN
#
#                R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1                                                     112.408176
# 2                                                            NaN
# 4                                                     487.798592
# 8                                                     976.510025
# 16                                                   1934.497314
# 32                                                   3882.850830
# 64                                                           NaN
# 128                                                          NaN
#
#                R--xlstm__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False_isd-bfloat16_ed-4096_nh-8_nb-32_vs-50304_wm-fused_ck-chunkwise--triton_xl_chunk_sk-native_sequence__triton_step_fused_sk-triton_fused_cs-128_akd-bfloat16
# P--batch_size
# 1                                                      45.143080
# 2                                                            NaN
# 4                                                     176.406242
# 8                                                     345.714592
# 16                                                    684.381256
# 32                                                   1377.384644
# 64                                                           NaN
# 128                                                          NaN

# %%
dataframe_dicts
# Out:
# [   R--llama3__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm
#  0                                        1258.790771
#  1                                        2535.061523
#  2                                        5086.016602
#  3                                       10172.586914
#  4                                       20338.792969
#  5                                       40673.058594
#  6                                       81386.695312
#  7                                      162828.968750                  ,
#     R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm
#  0                                        1653.675171
#  1                                        3329.413818
#  2                                        6662.367188
#  3                                       13310.563477
#  4                                       26637.548828
#  5                                       53416.453125
#  6                                      106548.476562
#  7                                      213746.765625                           ,
#     R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm
#  0                                        1973.957642
#  1                                        3961.426025
#  2                                        7923.171875
#  3                                       15845.697266
#  4                                                NaN
#  5                                                NaN
#  6                                                NaN
#  7                                                NaN                        ,
#     R--llama2__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm
#  0                                                NaN
#  1                                                NaN
#  2                                                NaN
#  3                                                NaN
#  4                                                NaN
#  5                                                NaN
#  6                                                NaN
#  7                                                NaN                  ]

# %%
for ctx in [2048, 4096, 8192, 16384, 32768]:
    df_base = pd.read_csv(f"../../outputs_kernel_benchmarks/2025-03-31_09-03-51__throughput__vllmpt260_lwu/hf_7B_throughput__pfl{ctx}_gl0_tcFalse_weightdtypebfloat16/results.csv")

    dataframe_dicts = [
        df_base.filter(regex="R.*llama3") , # / 1000.,
        df_base.filter(regex="R.*codestral"), #  / 1000.,
        df_base.filter(regex="R.*falcon"), #  / 1000.,
        df_base.filter(regex="R.*llama2")*float("nan") if ctx >= 8192 else df_base.filter(regex="R.*llama2"), #  / 1000.
    ]

    dataframe_dicts = [
        df.rename(columns={df.columns[0]:df.columns[0]+"_vllm"})
        for df in dataframe_dicts
    ]
    
    df = combined_raw_data[ctx]
    # print(df)
    # df = df[[df['P--batch_size'] not in [2, 128] ]]

    combined_raw_data[ctx] = pd.concat([df.reset_index(), *dataframe_dicts], axis=1).set_index("P--batch_size")

# %%
2048 * combined_raw_data[2048].index.values
# Out:
# array([  2048,   4096,   8192,  16384,  32768,  65536, 131072, 262144])

# %%
vals = (2048 * combined_raw_data[2048].index.values)[:, None] / combined_raw_data[
    2048
].filter(regex=".*R--.*")
vals
# Out:
#                R--llama2__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1                                                      43.268422
# 2                                                      44.762851
# 4                                                      42.857761
# 8                                                      43.140170
# 16                                                     42.979511
# 32                                                     42.609204
# 64                                                           NaN
# 128                                                          NaN
#
#                R--llama3__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1                                                      39.070358
# 2                                                      39.442655
# 4                                                      37.996749
# 8                                                      38.421985
# 16                                                     37.677809
# 32                                                     37.741091
# 64                                                           NaN
# 128                                                          NaN
#
#                R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1                                                      28.160046
# 2                                                            NaN
# 4                                                      28.223738
# 8                                                      28.114550
# 16                                                     27.660125
# 32                                                     27.271648
# 64                                                           NaN
# 128                                                          NaN
#
#                R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1                                                      18.219315
# 2                                                            NaN
# 4                                                      16.793816
# 8                                                      16.778118
# 16                                                     16.938767
# 32                                                     16.878320
# 64                                                           NaN
# 128                                                          NaN
#
#                R--xlstm__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False_isd-bfloat16_ed-4096_nh-8_nb-32_vs-50304_wm-fused_ck-chunkwise--triton_xl_chunk_sk-native_sequence__triton_step_fused_sk-triton_fused_cs-128_akd-bfloat16  \
# P--batch_size
# 1                                                      45.366865
# 2                                                            NaN
# 4                                                      46.438266
# 8                                                      47.391694
# 16                                                     47.879745
# 32                                                     47.580028
# 64                                                           NaN
# 128                                                          NaN
#
#                R--llama3__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
# P--batch_size
# 1                                                      33.958506
# 2                                                      36.761085
# 4                                                      38.639504
# 8                                                      39.280132
# 16                                                     39.963028
# 32                                                     39.232982
# 64                                                     38.819586
# 128                                                    38.924421
#
#                R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
# P--batch_size
# 1                                                      13.152900
# 2                                                      16.304756
# 4                                                      18.232729
# 8                                                      19.200647
# 16                                                     19.092933
# 32                                                     19.086761
# 64                                                     19.094387
# 128                                                    19.118052
#
#                R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
# P--batch_size
# 1                                                      15.599350
# 2                                                      17.041155
# 4                                                      17.617860
# 8                                                      17.861200
# 16                                                     17.843864
# 32                                                     17.883937
# 64                                                     17.891574
# 128                                                    17.899769
#
#                R--llama2__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm
# P--batch_size
# 1                                                      36.397409
# 2                                                      40.113168
# 4                                                      39.972395
# 8                                                      40.392477
# 16                                                     40.541957
# 32                                                     39.304383
# 64                                                     38.817360
# 128                                                    38.558759

# %%
pd.DataFrame(
    data=vals,
    columns=combined_raw_data[2048].filter(regex=".*R--.*").columns,
    index=combined_raw_data[2048].index,
)
# Out:
#                R--llama2__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1                                                      43.268422
# 2                                                      44.762851
# 4                                                      42.857761
# 8                                                      43.140170
# 16                                                     42.979511
# 32                                                     42.609204
# 64                                                           NaN
# 128                                                          NaN
#
#                R--llama3__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1                                                      39.070358
# 2                                                      39.442655
# 4                                                      37.996749
# 8                                                      38.421985
# 16                                                     37.677809
# 32                                                     37.741091
# 64                                                           NaN
# 128                                                          NaN
#
#                R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1                                                      28.160046
# 2                                                            NaN
# 4                                                      28.223738
# 8                                                      28.114550
# 16                                                     27.660125
# 32                                                     27.271648
# 64                                                           NaN
# 128                                                          NaN
#
#                R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1                                                      18.219315
# 2                                                            NaN
# 4                                                      16.793816
# 8                                                      16.778118
# 16                                                     16.938767
# 32                                                     16.878320
# 64                                                           NaN
# 128                                                          NaN
#
#                R--xlstm__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False_isd-bfloat16_ed-4096_nh-8_nb-32_vs-50304_wm-fused_ck-chunkwise--triton_xl_chunk_sk-native_sequence__triton_step_fused_sk-triton_fused_cs-128_akd-bfloat16  \
# P--batch_size
# 1                                                      45.366865
# 2                                                            NaN
# 4                                                      46.438266
# 8                                                      47.391694
# 16                                                     47.879745
# 32                                                     47.580028
# 64                                                           NaN
# 128                                                          NaN
#
#                R--llama3__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
# P--batch_size
# 1                                                      33.958506
# 2                                                      36.761085
# 4                                                      38.639504
# 8                                                      39.280132
# 16                                                     39.963028
# 32                                                     39.232982
# 64                                                     38.819586
# 128                                                    38.924421
#
#                R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
# P--batch_size
# 1                                                      13.152900
# 2                                                      16.304756
# 4                                                      18.232729
# 8                                                      19.200647
# 16                                                     19.092933
# 32                                                     19.086761
# 64                                                     19.094387
# 128                                                    19.118052
#
#                R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
# P--batch_size
# 1                                                      15.599350
# 2                                                      17.041155
# 4                                                      17.617860
# 8                                                      17.861200
# 16                                                     17.843864
# 32                                                     17.883937
# 64                                                     17.891574
# 128                                                    17.899769
#
#                R--llama2__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm
# P--batch_size
# 1                                                      36.397409
# 2                                                      40.113168
# 4                                                      39.972395
# 8                                                      40.392477
# 16                                                     40.541957
# 32                                                     39.304383
# 64                                                     38.817360
# 128                                                    38.558759

# %%
combined_raw_data[2048]["P--prefill_length"].values[0]
# Out:
# 2048.0

# %%
def compute_throughput_tokens_per_sec(raw_data_dict: dict[str, pd.DataFrame]):
    throughput_dict = {}
    for ctx, df in raw_data_dict.items():
        prefill_col = df.filter(regex="prefill").take([0], axis=1)
        tokens_per_sec_df = (ctx * df.index.values)[:, None] / (
            df.filter(regex=".*R--.*") / 1000
        )
        tokens_per_sec_df["P--prefill_length"] = int(prefill_col.values[0].item())
        # now make index a column again
        batch_col = tokens_per_sec_df.index
        tokens_per_sec_df["P--batch_size"] = batch_col

        tokens_per_sec_df = pd.concat(
            [
                tokens_per_sec_df["P--batch_size"],
                tokens_per_sec_df["P--prefill_length"],
                tokens_per_sec_df.drop(columns=["P--batch_size", "P--prefill_length"]),
            ],
            axis=1,
        )
        throughput_dict[ctx] = tokens_per_sec_df
    return throughput_dict

# %%
throughput_data = compute_throughput_tokens_per_sec(combined_raw_data)

# %%
throughput_data[2048]
# Out:
#                P--batch_size  P--prefill_length  \
# P--batch_size
# 1                          1               2048
# 2                          2               2048
# 4                          4               2048
# 8                          8               2048
# 16                        16               2048
# 32                        32               2048
# 64                        64               2048
# 128                      128               2048
#
#                R--llama2__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1                                                   43268.421905
# 2                                                   44762.851341
# 4                                                   42857.761063
# 8                                                   43140.169595
# 16                                                  42979.511056
# 32                                                  42609.204115
# 64                                                           NaN
# 128                                                          NaN
#
#                R--llama3__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1                                                   39070.357617
# 2                                                   39442.654572
# 4                                                   37996.748869
# 8                                                   38421.984778
# 16                                                  37677.808996
# 32                                                  37741.090702
# 64                                                           NaN
# 128                                                          NaN
#
#                R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1                                                   28160.046057
# 2                                                            NaN
# 4                                                   28223.737891
# 8                                                   28114.549562
# 16                                                  27660.125046
# 32                                                  27271.647745
# 64                                                           NaN
# 128                                                          NaN
#
#                R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1                                                   18219.315224
# 2                                                            NaN
# 4                                                   16793.816425
# 8                                                   16778.117562
# 16                                                  16938.767377
# 32                                                  16878.320303
# 64                                                           NaN
# 128                                                          NaN
#
#                R--xlstm__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False_isd-bfloat16_ed-4096_nh-8_nb-32_vs-50304_wm-fused_ck-chunkwise--triton_xl_chunk_sk-native_sequence__triton_step_fused_sk-triton_fused_cs-128_akd-bfloat16  \
# P--batch_size
# 1                                                   45366.864888
# 2                                                            NaN
# 4                                                   46438.265959
# 8                                                   47391.693553
# 16                                                  47879.744963
# 32                                                  47580.028067
# 64                                                           NaN
# 128                                                          NaN
#
#                R--llama3__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
# P--batch_size
# 1                                                   33958.506390
# 2                                                   36761.085396
# 4                                                   38639.504265
# 8                                                   39280.132417
# 16                                                  39963.028065
# 32                                                  39232.981927
# 64                                                  38819.585799
# 128                                                 38924.420760
#
#                R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
# P--batch_size
# 1                                                   13152.899905
# 2                                                   16304.756139
# 4                                                   18232.729063
# 8                                                   19200.647300
# 16                                                  19092.933461
# 32                                                  19086.760551
# 64                                                  19094.386650
# 128                                                 19118.051766
#
#                R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
# P--batch_size
# 1                                                   15599.350028
# 2                                                   17041.154730
# 4                                                   17617.859893
# 8                                                   17861.199945
# 16                                                  17843.864210
# 32                                                  17883.936590
# 64                                                  17891.573655
# 128                                                 17899.768667
#
#                R--llama2__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm
# P--batch_size
# 1                                                   36397.408559
# 2                                                   40113.168150
# 4                                                   39972.394696
# 8                                                   40392.476947
# 16                                                  40541.957460
# 32                                                  39304.383222
# 64                                                  38817.360029
# 128                                                 38558.758825

# %%
throughput_data[4096]
# Out:
#                P--batch_size  P--prefill_length  \
# P--batch_size
# 1                          1               4096
# 2                          2               4096
# 4                          4               4096
# 8                          8               4096
# 16                        16               4096
# 32                        32               4096
# 64                        64               4096
# 128                      128               4096
#
#                R--llama2__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1                                                   42848.982137
# 2                                                   41948.037715
# 4                                                   41570.430107
# 8                                                   41175.015780
# 16                                                  40829.126532
# 32                                                           NaN
# 64                                                           NaN
# 128                                                          NaN
#
#                R--llama3__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1                                                   37977.285679
# 2                                                   37001.546358
# 4                                                   36999.828257
# 8                                                   36326.226990
# 16                                                  36342.862547
# 32                                                           NaN
# 64                                                           NaN
# 128                                                          NaN
#
#                R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1                                                   28590.497929
# 2                                                            NaN
# 4                                                   27911.938548
# 8                                                   27585.127620
# 16                                                  27183.777762
# 32                                                           NaN
# 64                                                           NaN
# 128                                                          NaN
#
#                R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1                                                   18886.093571
# 2                                                            NaN
# 4                                                   16829.880641
# 8                                                   16873.206088
# 16                                                  16839.658242
# 32                                                           NaN
# 64                                                           NaN
# 128                                                          NaN
#
#                R--xlstm__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False_isd-bfloat16_ed-4096_nh-8_nb-32_vs-50304_wm-fused_ck-chunkwise--triton_xl_chunk_sk-native_sequence__triton_step_fused_sk-triton_fused_cs-128_akd-bfloat16  \
# P--batch_size
# 1                                                   46417.329706
# 2                                                            NaN
# 4                                                   47279.327491
# 8                                                   47952.123878
# 16                                                  47542.531585
# 32                                                           NaN
# 64                                                           NaN
# 128                                                          NaN
#
#                R--llama3__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
# P--batch_size
# 1                                                   35714.225216
# 2                                                   37011.441767
# 4                                                   38226.283521
# 8                                                   38302.052842
# 16                                                  37903.137094
# 32                                                  37577.124209
# 64                                                  37696.063114
# 128                                                 37636.706814
#
#                R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
# P--batch_size
# 1                                                   16596.886677
# 2                                                   18523.097854
# 4                                                   19515.751653
# 8                                                   19323.376390
# 16                                                  19289.546863
# 32                                                  19342.269281
# 64                                                  19347.089959
# 128                                                 19375.969465
#
#                R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
# P--batch_size
# 1                                                   17070.620490
# 2                                                   17616.989250
# 4                                                   17933.611112
# 8                                                   17955.117733
# 16                                                  17996.896013
# 32                                                  17990.926640
# 64                                                  18004.526024
# 128                                                 18011.114691
#
#                R--llama2__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm
# P--batch_size
# 1                                                   41664.386629
# 2                                                   39741.906562
# 4                                                   39240.887931
# 8                                                   38674.055067
# 16                                                  37855.113601
# 32                                                  37390.269353
# 64                                                  37306.181800
# 128                                                 37119.754234

# %%
throughput_data[8192]
# Out:
#                P--batch_size  P--prefill_length  \
# P--batch_size
# 1                          1               8192
# 2                          2               8192
# 4                          4               8192
# 8                          8               8192
# 16                        16               8192
# 32                        32               8192
# 64                        64               8192
# 128                      128               8192
#
#                R--llama2__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1                                                   38494.153325
# 2                                                   39020.934459
# 4                                                   38471.724294
# 8                                                   37863.720354
# 16                                                           NaN
# 32                                                           NaN
# 64                                                           NaN
# 128                                                          NaN
#
#                R--llama3__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1                                                   34237.030113
# 2                                                   34781.395733
# 4                                                   34166.171971
# 8                                                   33938.074356
# 16                                                           NaN
# 32                                                           NaN
# 64                                                           NaN
# 128                                                          NaN
#
#                R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1                                                   28426.926847
# 2                                                            NaN
# 4                                                   27700.586511
# 8                                                   27354.375570
# 16                                                           NaN
# 32                                                           NaN
# 64                                                           NaN
# 128                                                          NaN
#
#                R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1                                                   18104.708992
# 2                                                            NaN
# 4                                                   16303.002665
# 8                                                   16448.514036
# 16                                                           NaN
# 32                                                           NaN
# 64                                                           NaN
# 128                                                          NaN
#
#                R--xlstm__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False_isd-bfloat16_ed-4096_nh-8_nb-32_vs-50304_wm-fused_ck-chunkwise--triton_xl_chunk_sk-native_sequence__triton_step_fused_sk-triton_fused_cs-128_akd-bfloat16  \
# P--batch_size
# 1                                                   46283.343723
# 2                                                            NaN
# 4                                                   47957.827341
# 8                                                   47627.074616
# 16                                                           NaN
# 32                                                           NaN
# 64                                                           NaN
# 128                                                          NaN
#
#                R--llama3__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
# P--batch_size
# 1                                                   34151.819903
# 2                                                   36003.130947
# 4                                                   35974.152421
# 8                                                   35579.619494
# 16                                                  35343.474500
# 32                                                  35354.411253
# 64                                                  35199.812013
# 128                                                 35357.990035
#
#                R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
# P--batch_size
# 1                                                   17826.576300
# 2                                                   19145.740322
# 4                                                   19254.073216
# 8                                                   19346.053966
# 16                                                  19394.378252
# 32                                                  19436.256197
# 64                                                  19445.943217
# 128                                                 19460.336677
#
#                R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
# P--batch_size
# 1                                                   17325.818553
# 2                                                   17661.866901
# 4                                                   17795.539028
# 8                                                   17901.587883
# 16                                                  17968.527101
# 32                                                  18005.042892
# 64                                                  18025.934443
# 128                                                 18041.663749
#
#                R--llama2__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm
# P--batch_size
# 1                                                            NaN
# 2                                                            NaN
# 4                                                            NaN
# 8                                                            NaN
# 16                                                           NaN
# 32                                                           NaN
# 64                                                           NaN
# 128                                                          NaN

# %%
throughput_data[16384]
# Out:
#                P--batch_size  P--prefill_length  \
# P--batch_size
# 1.0                      1.0              16384
# 2.0                      2.0              16384
# 4.0                      4.0              16384
# 8.0                      8.0              16384
# 16.0                    16.0              16384
# 32.0                    32.0              16384
# 64.0                    64.0              16384
# NaN                      NaN              16384
#
#                R--llama2__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1.0                                                 33622.367570
# 2.0                                                 33205.432014
# 4.0                                                 33210.548703
# 8.0                                                          NaN
# 16.0                                                         NaN
# 32.0                                                         NaN
# 64.0                                                         NaN
# NaN                                                          NaN
#
#                R--llama3__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1.0                                                 30537.334739
# 2.0                                                 30043.477937
# 4.0                                                 29999.962393
# 8.0                                                          NaN
# 16.0                                                         NaN
# 32.0                                                         NaN
# 64.0                                                         NaN
# NaN                                                          NaN
#
#                R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1.0                                                 28288.303517
# 2.0                                                 28198.576002
# 4.0                                                 28013.662266
# 8.0                                                          NaN
# 16.0                                                         NaN
# 32.0                                                         NaN
# 64.0                                                         NaN
# NaN                                                          NaN
#
#                R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1.0                                                 18286.463866
# 2.0                                                 16210.222193
# 4.0                                                 16308.684318
# 8.0                                                          NaN
# 16.0                                                         NaN
# 32.0                                                         NaN
# 64.0                                                         NaN
# NaN                                                          NaN
#
#                R--xlstm__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False_isd-bfloat16_ed-4096_nh-8_nb-32_vs-50304_wm-fused_ck-chunkwise--triton_xl_chunk_sk-native_sequence__triton_step_fused_sk-triton_fused_cs-128_akd-bfloat16  \
# P--batch_size
# 1.0                                                 47676.759808
# 2.0                                                 48103.276135
# 4.0                                                 47595.969620
# 8.0                                                          NaN
# 16.0                                                         NaN
# 32.0                                                         NaN
# 64.0                                                         NaN
# NaN                                                          NaN
#
#                R--llama3__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
# P--batch_size
# 1.0                                                 31828.986614
# 2.0                                                 31457.340211
# 4.0                                                 31429.190161
# 8.0                                                 31354.293394
# 16.0                                                31403.845621
# 32.0                                                31437.895345
# 64.0                                                31479.064496
# NaN                                                          NaN
#
#                R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
# P--batch_size
# 1.0                                                 19326.480203
# 2.0                                                 19425.729700
# 4.0                                                 19463.637063
# 8.0                                                 19604.551307
# 16.0                                                19631.537219
# 32.0                                                19675.995575
# 64.0                                                19666.635652
# NaN                                                          NaN
#
#                R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
# P--batch_size
# 1.0                                                 16394.304477
# 2.0                                                 16823.052509
# 4.0                                                 16879.285037
# 8.0                                                 16927.327541
# 16.0                                                16941.553302
# 32.0                                                16945.829118
# 64.0                                                16946.705296
# NaN                                                          NaN
#
#                R--llama2__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm
# P--batch_size
# 1.0                                                          NaN
# 2.0                                                          NaN
# 4.0                                                          NaN
# 8.0                                                          NaN
# 16.0                                                         NaN
# 32.0                                                         NaN
# 64.0                                                         NaN
# NaN                                                          NaN

# %%
throughput_data[32768]
# Out:
#                P--batch_size  P--prefill_length  \
# P--batch_size
# 1.0                      1.0              32768
# 2.0                      2.0              32768
# 4.0                      4.0              32768
# 8.0                      8.0              32768
# 16.0                    16.0              32768
# 32.0                    32.0              32768
# 64.0                    64.0              32768
# NaN                      NaN              32768
#
#                R--llama2__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1.0                                                 26310.012100
# 2.0                                                 26223.974696
# 4.0                                                          NaN
# 8.0                                                          NaN
# 16.0                                                         NaN
# 32.0                                                         NaN
# 64.0                                                         NaN
# NaN                                                          NaN
#
#                R--llama3__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1.0                                                 24394.353153
# 2.0                                                 24320.276207
# 4.0                                                          NaN
# 8.0                                                          NaN
# 16.0                                                         NaN
# 32.0                                                         NaN
# 64.0                                                         NaN
# NaN                                                          NaN
#
#                R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1.0                                                 28330.467346
# 2.0                                                 28108.125235
# 4.0                                                          NaN
# 8.0                                                          NaN
# 16.0                                                         NaN
# 32.0                                                         NaN
# 64.0                                                         NaN
# NaN                                                          NaN
#
#                R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 1.0                                                 18333.455683
# 2.0                                                 16026.531272
# 4.0                                                          NaN
# 8.0                                                          NaN
# 16.0                                                         NaN
# 32.0                                                         NaN
# 64.0                                                         NaN
# NaN                                                          NaN
#
#                R--xlstm__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False_isd-bfloat16_ed-4096_nh-8_nb-32_vs-50304_wm-fused_ck-chunkwise--triton_xl_chunk_sk-native_sequence__triton_step_fused_sk-triton_fused_cs-128_akd-bfloat16  \
# P--batch_size
# 1.0                                                 48042.544967
# 2.0                                                 47642.253932
# 4.0                                                          NaN
# 8.0                                                          NaN
# 16.0                                                         NaN
# 32.0                                                         NaN
# 64.0                                                         NaN
# NaN                                                          NaN
#
#                R--llama3__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
# P--batch_size
# 1.0                                                 26031.331610
# 2.0                                                 25851.838069
# 4.0                                                 25771.052332
# 8.0                                                 25769.649570
# 16.0                                                25777.734244
# 32.0                                                25780.603580
# 64.0                                                25767.749777
# NaN                                                          NaN
#
#                R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
# P--batch_size
# 1.0                                                 19815.257904
# 2.0                                                 19683.945456
# 4.0                                                 19673.487863
# 8.0                                                 19694.432956
# 16.0                                                19682.291467
# 32.0                                                19630.206400
# 64.0                                                19682.608965
# NaN                                                          NaN
#
#                R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
# P--batch_size
# 1.0                                                 16600.153574
# 2.0                                                 16543.537499
# 4.0                                                 16542.869708
# 8.0                                                 16543.544636
# 16.0                                                16545.842047
# 32.0                                                16536.837563
# 64.0                                                         NaN
# NaN                                                          NaN
#
#                R--llama2__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm
# P--batch_size
# 1.0                                                          NaN
# 2.0                                                          NaN
# 4.0                                                          NaN
# 8.0                                                          NaN
# 16.0                                                         NaN
# 32.0                                                         NaN
# 64.0                                                         NaN
# NaN                                                          NaN

# %%
throughput_32768 = throughput_data[32768].loc[
    throughput_data[32768]["P--batch_size"] == 2.0
]
throughput_16384 = throughput_data[16384].loc[
    throughput_data[16384]["P--batch_size"] == 4.0
]
throughput_8192 = throughput_data[8192].loc[
    throughput_data[8192]["P--batch_size"] == 8.0
]
throughput_4096 = throughput_data[4096].loc[
    throughput_data[4096]["P--batch_size"] == 16.0
]
throughput_2048 = throughput_data[2048].loc[
    throughput_data[2048]["P--batch_size"] == 32.0
]

# %%
throughput_df = pd.concat(
    [
        throughput_2048,
        throughput_4096,
        throughput_8192,
        throughput_16384,
        throughput_32768,
    ]
)

# %%
throughput_df
# Out:
#                P--batch_size  P--prefill_length  \
# P--batch_size
# 32.0                    32.0               2048
# 16.0                    16.0               4096
# 8.0                      8.0               8192
# 4.0                      4.0              16384
# 2.0                      2.0              32768
#
#                R--llama2__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 32.0                                                42609.204115
# 16.0                                                40829.126532
# 8.0                                                 37863.720354
# 4.0                                                 33210.548703
# 2.0                                                 26223.974696
#
#                R--llama3__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 32.0                                                37741.090702
# 16.0                                                36342.862547
# 8.0                                                 33938.074356
# 4.0                                                 29999.962393
# 2.0                                                 24320.276207
#
#                R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 32.0                                                27271.647745
# 16.0                                                27183.777762
# 8.0                                                 27354.375570
# 4.0                                                 28013.662266
# 2.0                                                 28108.125235
#
#                R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 32.0                                                16878.320303
# 16.0                                                16839.658242
# 8.0                                                 16448.514036
# 4.0                                                 16308.684318
# 2.0                                                 16026.531272
#
#                R--xlstm__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False_isd-bfloat16_ed-4096_nh-8_nb-32_vs-50304_wm-fused_ck-chunkwise--triton_xl_chunk_sk-native_sequence__triton_step_fused_sk-triton_fused_cs-128_akd-bfloat16  \
# P--batch_size
# 32.0                                                47580.028067
# 16.0                                                47542.531585
# 8.0                                                 47627.074616
# 4.0                                                 47595.969620
# 2.0                                                 47642.253932
#
#                R--llama3__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
# P--batch_size
# 32.0                                                39232.981927
# 16.0                                                37903.137094
# 8.0                                                 35579.619494
# 4.0                                                 31429.190161
# 2.0                                                 25851.838069
#
#                R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
# P--batch_size
# 32.0                                                19086.760551
# 16.0                                                19289.546863
# 8.0                                                 19346.053966
# 4.0                                                 19463.637063
# 2.0                                                 19683.945456
#
#                R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
# P--batch_size
# 32.0                                                17883.936590
# 16.0                                                17996.896013
# 8.0                                                 17901.587883
# 4.0                                                 16879.285037
# 2.0                                                 16543.537499
#
#                R--llama2__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm
# P--batch_size
# 32.0                                                39304.383222
# 16.0                                                37855.113601
# 8.0                                                          NaN
# 4.0                                                          NaN
# 2.0                                                          NaN

# %%
# with open("throughput_vllm_df.p", "wb") as f:
#     pickle.dump(throughput_df, f)

# %%
throughput_df
# Out:
#                P--batch_size  P--prefill_length  \
# P--batch_size
# 32.0                    32.0               2048
# 16.0                    16.0               4096
# 8.0                      8.0               8192
# 4.0                      4.0              16384
# 2.0                      2.0              32768
#
#                R--llama2__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 32.0                                                42609.204115
# 16.0                                                40829.126532
# 8.0                                                 37863.720354
# 4.0                                                 33210.548703
# 2.0                                                 26223.974696
#
#                R--llama3__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 32.0                                                37741.090702
# 16.0                                                36342.862547
# 8.0                                                 33938.074356
# 4.0                                                 29999.962393
# 2.0                                                 24320.276207
#
#                R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 32.0                                                27271.647745
# 16.0                                                27183.777762
# 8.0                                                 27354.375570
# 4.0                                                 28013.662266
# 2.0                                                 28108.125235
#
#                R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
# P--batch_size
# 32.0                                                16878.320303
# 16.0                                                16839.658242
# 8.0                                                 16448.514036
# 4.0                                                 16308.684318
# 2.0                                                 16026.531272
#
#                R--xlstm__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False_isd-bfloat16_ed-4096_nh-8_nb-32_vs-50304_wm-fused_ck-chunkwise--triton_xl_chunk_sk-native_sequence__triton_step_fused_sk-triton_fused_cs-128_akd-bfloat16  \
# P--batch_size
# 32.0                                                47580.028067
# 16.0                                                47542.531585
# 8.0                                                 47627.074616
# 4.0                                                 47595.969620
# 2.0                                                 47642.253932
#
#                R--llama3__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
# P--batch_size
# 32.0                                                39232.981927
# 16.0                                                37903.137094
# 8.0                                                 35579.619494
# 4.0                                                 31429.190161
# 2.0                                                 25851.838069
#
#                R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
# P--batch_size
# 32.0                                                19086.760551
# 16.0                                                19289.546863
# 8.0                                                 19346.053966
# 4.0                                                 19463.637063
# 2.0                                                 19683.945456
#
#                R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
# P--batch_size
# 32.0                                                17883.936590
# 16.0                                                17996.896013
# 8.0                                                 17901.587883
# 4.0                                                 16879.285037
# 2.0                                                 16543.537499
#
#                R--llama2__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm
# P--batch_size
# 32.0                                                39304.383222
# 16.0                                                37855.113601
# 8.0                                                          NaN
# 4.0                                                          NaN
# 2.0                                                          NaN

# %%
combined_raw_data
# Out:
# {2048:                P--prefill_length  \
#  P--batch_size
#  1                         2048.0
#  2                         2048.0
#  4                         2048.0
#  8                         2048.0
#  16                        2048.0
#  32                        2048.0
#  64                        2048.0
#  128                          NaN
#
#                 R--llama2__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
#  P--batch_size
#  1                                                      47.332440
#  2                                                      91.504448
#  4                                                     191.143909
#  8                                                     379.785248
#  16                                                    762.409790
#  32                                                   1538.071442
#  64                                                           NaN
#  128                                                          NaN
#
#                 R--llama3__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
#  P--batch_size
#  1                                                      52.418256
#  2                                                     103.846966
#  4                                                     215.597393
#  8                                                     426.422531
#  16                                                    869.689636
#  32                                                   1736.462799
#  64                                                           NaN
#  128                                                          NaN
#
#                 R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
#  P--batch_size
#  1                                                      72.727154
#  2                                                            NaN
#  4                                                     290.252129
#  8                                                     582.758759
#  16                                                   1184.665649
#  32                                                   2403.081787
#  64                                                           NaN
#  128                                                          NaN
#
#                 R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
#  P--batch_size
#  1                                                     112.408176
#  2                                                            NaN
#  4                                                     487.798592
#  8                                                     976.510025
#  16                                                   1934.497314
#  32                                                   3882.850830
#  64                                                           NaN
#  128                                                          NaN
#
#                 R--xlstm__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False_isd-bfloat16_ed-4096_nh-8_nb-32_vs-50304_wm-fused_ck-chunkwise--triton_xl_chunk_sk-native_sequence__triton_step_fused_sk-triton_fused_cs-128_akd-bfloat16  \
#  P--batch_size
#  1                                                      45.143080
#  2                                                            NaN
#  4                                                     176.406242
#  8                                                     345.714592
#  16                                                    684.381256
#  32                                                   1377.384644
#  64                                                           NaN
#  128                                                          NaN
#
#                 R--llama3__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
#  P--batch_size
#  1                                                      60.308895
#  2                                                     111.422173
#  4                                                     212.011002
#  8                                                     417.106537
#  16                                                    819.957886
#  32                                                   1670.431274
#  64                                                   3376.439941
#  128                                                  6734.692383
#
#                 R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
#  P--batch_size
#  1                                                     155.707108
#  2                                                     251.215042
#  4                                                     449.301910
#  8                                                     853.304565
#  16                                                   1716.237061
#  32                                                   3433.584229
#  64                                                   6864.425781
#  128                                                 13711.857422
#
#                 R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
#  P--batch_size
#  1                                                     131.287521
#  2                                                     240.359299
#  4                                                     464.982697
#  8                                                     917.295593
#  16                                                   1836.373535
#  32                                                   3664.517578
#  64                                                   7325.906738
#  128                                                 14645.105469
#
#                 R--llama2__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm
#  P--batch_size
#  1                                                      56.267742
#  2                                                     102.111107
#  4                                                     204.941437
#  8                                                     405.620087
#  16                                                    808.249084
#  32                                                   1667.396729
#  64                                                   3376.633545
#  128                                                  6798.559082                    ,
#  4096:                P--prefill_length  \
#  P--batch_size
#  1                         4096.0
#  2                         4096.0
#  4                         4096.0
#  8                         4096.0
#  16                        4096.0
#  32                        4096.0
#  64                        4096.0
#  128                          NaN
#
#                 R--llama2__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
#  P--batch_size
#  1                                                      95.591536
#  2                                                     195.289230
#  4                                                     394.126305
#  8                                                     795.822403
#  16                                                   1605.128632
#  32                                                           NaN
#  64                                                           NaN
#  128                                                          NaN
#
#                 R--llama3__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
#  P--batch_size
#  1                                                     107.853943
#  2                                                     221.396152
#  4                                                     442.812866
#  8                                                     902.047989
#  16                                                   1803.270172
#  32                                                           NaN
#  64                                                           NaN
#  128                                                          NaN
#
#                 R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
#  P--batch_size
#  1                                                     143.264381
#  2                                                            NaN
#  4                                                     586.988968
#  8                                                    1187.886475
#  16                                                   2410.849609
#  32                                                           NaN
#  64                                                           NaN
#  128                                                          NaN
#
#                 R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
#  P--batch_size
#  1                                                     216.879154
#  2                                                            NaN
#  4                                                     973.506607
#  8                                                    1942.013855
#  16                                                   3891.765442
#  32                                                           NaN
#  64                                                           NaN
#  128                                                          NaN
#
#                 R--xlstm__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False_isd-bfloat16_ed-4096_nh-8_nb-32_vs-50304_wm-fused_ck-chunkwise--triton_xl_chunk_sk-native_sequence__triton_step_fused_sk-triton_fused_cs-128_akd-bfloat16  \
#  P--batch_size
#  1                                                      88.242905
#  2                                                            NaN
#  4                                                     346.536232
#  8                                                     683.348251
#  16                                                   1378.470978
#  32                                                           NaN
#  64                                                           NaN
#  128                                                          NaN
#
#                 R--llama3__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
#  P--batch_size
#  1                                                     114.688194
#  2                                                     221.336960
#  4                                                     428.605621
#  8                                                     855.515503
#  16                                                   1729.038940
#  32                                                   3488.079590
#  64                                                   6954.147949
#  128                                                 13930.230469
#
#                 R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
#  P--batch_size
#  1                                                     246.793274
#  2                                                     442.258636
#  4                                                     839.526978
#  8                                                    1695.769897
#  16                                                   3397.487793
#  32                                                   6776.454102
#  64                                                  13549.531250
#  128                                                 27058.671875
#
#                 R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
#  P--batch_size
#  1                                                     239.944412
#  2                                                     465.005676
#  4                                                     913.591797
#  8                                                    1824.994995
#  16                                                   3641.516846
#  32                                                   7285.450195
#  64                                                  14559.894531
#  128                                                 29109.136719
#
#                 R--llama2__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm
#  P--batch_size
#  1                                                      98.309380
#  2                                                     206.130020
#  4                                                     417.523682
#  8                                                     847.286377
#  16                                                   1731.232422
#  32                                                   3505.510986
#  64                                                   7026.824707
#  128                                                 14124.231445                    ,
#  8192:                P--prefill_length  \
#  P--batch_size
#  1                         8192.0
#  2                         8192.0
#  4                         8192.0
#  8                         8192.0
#  16                        8192.0
#  32                        8192.0
#  64                        8192.0
#  128                          NaN
#
#                 R--llama2__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
#  P--batch_size
#  1                                                     212.811539
#  2                                                     419.877182
#  4                                                     851.742432
#  8                                                    1730.838898
#  16                                                           NaN
#  32                                                           NaN
#  64                                                           NaN
#  128                                                          NaN
#
#                 R--llama3__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
#  P--batch_size
#  1                                                     239.273090
#  2                                                     471.056427
#  4                                                     959.077301
#  8                                                    1931.046509
#  16                                                           NaN
#  32                                                           NaN
#  64                                                           NaN
#  128                                                          NaN
#
#                 R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
#  P--batch_size
#  1                                                     288.177475
#  2                                                            NaN
#  4                                                    1182.935242
#  8                                                    2395.814148
#  16                                                           NaN
#  32                                                           NaN
#  64                                                           NaN
#  128                                                          NaN
#
#                 R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
#  P--batch_size
#  1                                                     452.478966
#  2                                                            NaN
#  4                                                    2009.936493
#  8                                                    3984.311279
#  16                                                           NaN
#  32                                                           NaN
#  64                                                           NaN
#  128                                                          NaN
#
#                 R--xlstm__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False_isd-bfloat16_ed-4096_nh-8_nb-32_vs-50304_wm-fused_ck-chunkwise--triton_xl_chunk_sk-native_sequence__triton_step_fused_sk-triton_fused_cs-128_akd-bfloat16  \
#  P--batch_size
#  1                                                     176.996719
#  2                                                            NaN
#  4                                                     683.266983
#  8                                                    1376.024048
#  16                                                           NaN
#  32                                                           NaN
#  64                                                           NaN
#  128                                                          NaN
#
#                 R--llama3__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
#  P--batch_size
#  1                                                     239.870087
#  2                                                     455.071533
#  4                                                     910.876221
#  8                                                    1841.953369
#  16                                                   3708.520508
#  32                                                   7414.746582
#  64                                                  14894.625000
#  128                                                 29655.984375
#
#                 R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
#  P--batch_size
#  1                                                     459.538605
#  2                                                     855.751709
#  4                                                    1701.873657
#  8                                                    3387.564209
#  16                                                   6758.247070
#  32                                                  13487.371094
#  64                                                  26961.304688
#  128                                                 53882.726562
#
#                 R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
#  P--batch_size
#  1                                                     472.820374
#  2                                                     927.648254
#  4                                                    1841.360352
#  8                                                    3660.904297
#  16                                                   7294.532227
#  32                                                  14559.476562
#  64                                                  29085.205078
#  128                                                 58119.695312
#
#                 R--llama2__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm
#  P--batch_size
#  1                                                            NaN
#  2                                                            NaN
#  4                                                            NaN
#  8                                                            NaN
#  16                                                           NaN
#  32                                                           NaN
#  64                                                           NaN
#  128                                                          NaN                    ,
#  16384:                P--prefill_length  \
#  P--batch_size
#  1.0                      16384.0
#  2.0                      16384.0
#  4.0                      16384.0
#  8.0                      16384.0
#  16.0                     16384.0
#  32.0                     16384.0
#  64.0                     16384.0
#  NaN                          NaN
#
#                 R--llama2__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
#  P--batch_size
#  1.0                                                   487.294655
#  2.0                                                   986.826492
#  4.0                                                  1973.348907
#  8.0                                                          NaN
#  16.0                                                         NaN
#  32.0                                                         NaN
#  64.0                                                         NaN
#  NaN                                                          NaN
#
#                 R--llama3__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
#  P--batch_size
#  1.0                                                   536.523575
#  2.0                                                  1090.685974
#  4.0                                                  2184.536072
#  8.0                                                          NaN
#  16.0                                                         NaN
#  32.0                                                         NaN
#  64.0                                                         NaN
#  NaN                                                          NaN
#
#                 R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
#  P--batch_size
#  1.0                                                   579.179306
#  2.0                                                  1162.044495
#  4.0                                                  2339.429932
#  8.0                                                          NaN
#  16.0                                                         NaN
#  32.0                                                         NaN
#  64.0                                                         NaN
#  NaN                                                          NaN
#
#                 R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
#  P--batch_size
#  1.0                                                   895.963272
#  2.0                                                  2021.440521
#  4.0                                                  4018.472534
#  8.0                                                          NaN
#  16.0                                                         NaN
#  32.0                                                         NaN
#  64.0                                                         NaN
#  NaN                                                          NaN
#
#                 R--xlstm__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False_isd-bfloat16_ed-4096_nh-8_nb-32_vs-50304_wm-fused_ck-chunkwise--triton_xl_chunk_sk-native_sequence__triton_step_fused_sk-triton_fused_cs-128_akd-bfloat16  \
#  P--batch_size
#  1.0                                                   343.647514
#  2.0                                                   681.201004
#  4.0                                                  1376.923309
#  8.0                                                          NaN
#  16.0                                                         NaN
#  32.0                                                         NaN
#  64.0                                                         NaN
#  NaN                                                          NaN
#
#                 R--llama3__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
#  P--batch_size
#  1.0                                                   514.750916
#  2.0                                                  1041.664673
#  4.0                                                  2085.195312
#  8.0                                                  4180.352539
#  16.0                                                 8347.512695
#  32.0                                                16676.943359
#  64.0                                                33310.265625
#  NaN                                                 66664.484375
#
#                 R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
#  P--batch_size
#  1.0                                                   847.748779
#  2.0                                                  1686.834961
#  4.0                                                  3367.099365
#  8.0                                                  6685.794434
#  16.0                                                13353.208008
#  32.0                                                26646.072266
#  64.0                                                53317.507812
#  NaN                                                106907.210938
#
#                 R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
#  P--batch_size
#  1.0                                                   999.371460
#  2.0                                                  1947.803467
#  4.0                                                  3882.628906
#  8.0                                                  7743.218750
#  16.0                                                15473.433594
#  32.0                                                30939.058594
#  64.0                                                61874.917969
#  NaN                                                123744.414062
#
#                 R--llama2__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm
#  P--batch_size
#  1.0                                                          NaN
#  2.0                                                          NaN
#  4.0                                                          NaN
#  8.0                                                          NaN
#  16.0                                                         NaN
#  32.0                                                         NaN
#  64.0                                                         NaN
#  NaN                                                          NaN                    ,
#  32768:                P--prefill_length  \
#  P--batch_size
#  1.0                      32768.0
#  2.0                      32768.0
#  4.0                      32768.0
#  8.0                      32768.0
#  16.0                     32768.0
#  32.0                     32768.0
#  64.0                     32768.0
#  NaN                          NaN
#
#                 R--llama2__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
#  P--batch_size
#  1.0                                                  1245.457428
#  2.0                                                  2499.087219
#  4.0                                                          NaN
#  8.0                                                          NaN
#  16.0                                                         NaN
#  32.0                                                         NaN
#  64.0                                                         NaN
#  NaN                                                          NaN
#
#                 R--llama3__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
#  P--batch_size
#  1.0                                                  1343.261688
#  2.0                                                  2694.706238
#  4.0                                                          NaN
#  8.0                                                          NaN
#  16.0                                                         NaN
#  32.0                                                         NaN
#  64.0                                                         NaN
#  NaN                                                          NaN
#
#                 R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
#  P--batch_size
#  1.0                                                  1156.634644
#  2.0                                                  2331.567810
#  4.0                                                          NaN
#  8.0                                                          NaN
#  16.0                                                         NaN
#  32.0                                                         NaN
#  64.0                                                         NaN
#  NaN                                                          NaN
#
#                 R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False  \
#  P--batch_size
#  1.0                                                  1787.333527
#  2.0                                                  4089.219238
#  4.0                                                          NaN
#  8.0                                                          NaN
#  16.0                                                         NaN
#  32.0                                                         NaN
#  64.0                                                         NaN
#  NaN                                                          NaN
#
#                 R--xlstm__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False_isd-bfloat16_ed-4096_nh-8_nb-32_vs-50304_wm-fused_ck-chunkwise--triton_xl_chunk_sk-native_sequence__triton_step_fused_sk-triton_fused_cs-128_akd-bfloat16  \
#  P--batch_size
#  1.0                                                   682.062119
#  2.0                                                  1375.585632
#  4.0                                                          NaN
#  8.0                                                          NaN
#  16.0                                                         NaN
#  32.0                                                         NaN
#  64.0                                                         NaN
#  NaN                                                          NaN
#
#                 R--llama3__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
#  P--batch_size
#  1.0                                                  1258.790771
#  2.0                                                  2535.061523
#  4.0                                                  5086.016602
#  8.0                                                 10172.586914
#  16.0                                                20338.792969
#  32.0                                                40673.058594
#  64.0                                                81386.695312
#  NaN                                                162828.968750
#
#                 R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
#  P--batch_size
#  1.0                                                  1653.675171
#  2.0                                                  3329.413818
#  4.0                                                  6662.367188
#  8.0                                                 13310.563477
#  16.0                                                26637.548828
#  32.0                                                53416.453125
#  64.0                                               106548.476562
#  NaN                                                213746.765625
#
#                 R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm  \
#  P--batch_size
#  1.0                                                  1973.957642
#  2.0                                                  3961.426025
#  4.0                                                  7923.171875
#  8.0                                                 15845.697266
#  16.0                                                         NaN
#  32.0                                                         NaN
#  64.0                                                         NaN
#  NaN                                                          NaN
#
#                 R--llama2__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm
#  P--batch_size
#  1.0                                                          NaN
#  2.0                                                          NaN
#  4.0                                                          NaN
#  8.0                                                          NaN
#  16.0                                                         NaN
#  32.0                                                         NaN
#  64.0                                                         NaN
#  NaN                                                          NaN                    }

# %% [markdown]
# ## Plotting the raw data

# %%
column_name_mapping = {
    "P--batch_size": "BS",
    "P--prefill_length": "CTX",
    "R--llama2__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False": "llama2",
    "R--llama3__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False": "llama3",
    "R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False": "codestral_mamba",
    "R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False": "falcon_mamba",
    "R--xlstm__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False_isd-bfloat16_ed-4096_nh-8_nb-32_vs-50304_wm-fused_ck-chunkwise--triton_xl_chunk_sk-native_sequence__triton_step_fused_sk-triton_fused_cs-128_akd-bfloat16": "xlstm",
}

# %%
throughput_df.columns
# Out:
# Index(['P--batch_size', 'P--prefill_length',
#        'R--llama2__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False',
#        'R--llama3__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False',
#        'R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False',
#        'R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False',
#        'R--xlstm__tcm__ampdt-bfloat16__wdt-bfloat16__ucgg-True_ucgm-False_isd-bfloat16_ed-4096_nh-8_nb-32_vs-50304_wm-fused_ck-chunkwise--triton_xl_chunk_sk-native_sequence__triton_step_fused_sk-triton_fused_cs-128_akd-bfloat16',
#        'R--llama3__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm',
#        'R--codestral_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm',
#        'R--falcon_mamba__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm',
#        'R--llama2__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm'],
#       dtype='object')

# %%
new_col_names = [column_name_mapping.get(col, col) for col in throughput_df.columns]
throughput_df.columns = new_col_names

# %%
plot_throughput_df = throughput_df.round(0).astype(int)
plot_throughput_df
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[210], line 1
# ----> 1 plot_throughput_df = throughput_df.round(0).astype(int)
#       2 plot_throughput_df
#
# File /nfs-gpu/xlstm/miniforge3/envs/xlstmpt260cu126_speedvllm2/lib/python3.11/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File /nfs-gpu/xlstm/miniforge3/envs/xlstmpt260cu126_speedvllm2/lib/python3.11/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File /nfs-gpu/xlstm/miniforge3/envs/xlstmpt260cu126_speedvllm2/lib/python3.11/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File /nfs-gpu/xlstm/miniforge3/envs/xlstmpt260cu126_speedvllm2/lib/python3.11/site-packages/pandas/core/internals/blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File /nfs-gpu/xlstm/miniforge3/envs/xlstmpt260cu126_speedvllm2/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File /nfs-gpu/xlstm/miniforge3/envs/xlstmpt260cu126_speedvllm2/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File /nfs-gpu/xlstm/miniforge3/envs/xlstmpt260cu126_speedvllm2/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:101, in _astype_nansafe(arr, dtype, copy, skipna)
#      96     return lib.ensure_string_array(
#      97         arr, skipna=skipna, convert_na_value=False
#      98     ).reshape(shape)
#     100 elif np.issubdtype(arr.dtype, np.floating) and dtype.kind in "iu":
# --> 101     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     103 elif arr.dtype == object:
#     104     # if we have a datetime/timedelta array of objects
#     105     # then coerce to datetime64[ns] and use DatetimeArray.astype
#     107     if lib.is_np_dtype(dtype, "M"):
#
# File /nfs-gpu/xlstm/miniforge3/envs/xlstmpt260cu126_speedvllm2/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:145, in _astype_float_to_int_nansafe(values, dtype, copy)
#     141 """
#     142 astype with a check preventing converting NaN to an meaningless integer value.
#     143 """
#     144 if not np.isfinite(values).all():
# --> 145     raise IntCastingNaNError(
#     146         "Cannot convert non-finite values (NA or inf) to integer"
#     147     )
#     148 if dtype.kind == "u":
#     149     # GH#45151
#     150     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
fig = rc_context_wrapper(
    func=create_runtime_bar_plot,
    data_df=plot_throughput_df,
    group_col_names=["BS", "CTX"],
    style_dict=style_dict,
    figsize=(2 * 12 * 1 / 2.54, 1.5 * 8 * 1 / 2.54),
    y_label="Tokens per Second",
    legend_args={
        "loc": "lower center",
        "ncol": 3,
        "bbox_to_anchor": (0.0, 1.02, 1.0, 0.502),
        "frameon": False,
        "facecolor": "white",
    },
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[211], line 1
# ----> 1 fig = rc_context_wrapper(
#       2     func=create_runtime_bar_plot,
#       3     data_df=plot_throughput_df,
#       4     group_col_names=["BS", "CTX"],
#       5     style_dict=style_dict,
#       6     figsize=(2 * 12 * 1 / 2.54, 1.5 * 8 * 1 / 2.54),
#       7     y_label="Tokens per Second",
#       8     legend_args={
#       9         "loc": "lower center",
#      10         "ncol": 3,
#      11         "bbox_to_anchor": (0.0, 1.02, 1.0, 0.502),
#      12         "frameon": False,
#      13         "facecolor": "white",
#      14     },
#      15 )
#
# File /nfs-gpu/xlstm/miniforge3/envs/xlstmpt260cu126_speedvllm2/lib/python3.11/site-packages/mlstm_kernels/utils/benchmark/plot_results.py:44, in rc_context_wrapper(func, **kwargs)
#      30 def rc_context_wrapper(func: Callable, **kwargs):
#      31     with mpl.rc_context(
#      32         rc={
#      33             "text.usetex": False,
#    (...)     42         }
#      43     ):
# ---> 44         return func(**kwargs)
#
# File /nfs-gpu/xlstm/miniforge3/envs/xlstmpt260cu126_speedvllm2/lib/python3.11/site-packages/mlstm_kernels/utils/benchmark/plot_results.py:370, in create_runtime_bar_plot(data_df, group_col_names, title, bar_label_font_size, bar_length_df, plot_column_order, style_dict, fillna_val, fillna_exclude_cols, fillna_str, legend_args, legend_order, figsize, grid_alpha, yticks, ylim, y_label, x_label, ax, add_colname)
#     368     rects = ax.bar(x + offset, bar_length_df[col], width, label=col)
#     369 else:
# --> 370     rects = ax.bar(x + offset, bar_length_df[col], width, **style_dict[col])
#     371 ax.bar_label(rects, labels=raw_data_df[col], fontsize=bar_label_font_size)
#     372 multiplier += 1
#
# KeyError: 'R--llama3__ampdt-bfloat16__wdt-bfloat16__ucgg-False_ucgm-False_vllm'

# %%
fig

# %%
savefig(fig, "throughput")
